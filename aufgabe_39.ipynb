# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(-10, 10, 1000)

r = [t ** 2, (t ** 2 - 4)]
s = [t * (t - 2), t ** 2]

plt.figure(figsize=(6,6))
plt.plot(*r, 'r')
plt.plot(*s, 'b')
plt.axis('equal')
plt.xlim([-2, 10])
plt.ylim([-1, 10])
plt.show()
